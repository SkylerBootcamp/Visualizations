# %%
# Out:
# ERROR: unknown command "lis" - maybe you meant "list"

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.1
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.14.0
# backcall                         0.2.0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x='month', y='qty', data=df, hue='month', legend=False, palette='tab10')
# Out:
# <Axes: xlabel='month', ylabel='qty'>

# %%
sns.barplot(x='month', y='qty', data=df, hue='month', palette = 'deep')
# Out:
# <Axes: xlabel='month', ylabel='qty'>

# %%
sns.barplot(x='month', y='qty', data=df, hue='qty', palette='magma', legend=False)
# Out:
# <Axes: xlabel='month', ylabel='qty'>

# %%
sns.barplot(x=["Jan", "Mar", "Aug"], y=[70, 30, 50], hue='Auto')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-39984eb14aa3> in <cell line: 1>()
# ----> 1 sns.barplot(x=["Jan", "Mar", "Aug"], y=[70, 30, 50], hue='Auto')
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338         estimator = "size"
#    2339
# -> 2340     p = _CategoricalAggPlotter(
#    2341         data=data,
#    2342         variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
# ...

# %%
sns.barplot(x='month', y='qty', data=df)
# Out:
# <Axes: xlabel='month', ylabel='qty'>

# %%
plt.plot(df['month'], df['qty'], df['discounts'])

# %%
palette = sns.color_palette() # Default color palette
sns.palplot(palette)

# %%
sns.color_palette("rocket", as_cmap=True)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_avg_data.csv')
df
# Out:
#        store_loc  num_emp  avg_emp_tenure_in_years  avg_emp_rating  \
# 0        Atlanta       17                        1               3
# 1         Austin       12                        6               4
# 2        Chicago       22                        3               3
# 3         Denver       21                        5               4
# 4        Detroit       10                        1               2
# 5          Miami       30                        2               3
# 6       Portland       13                        4               4
# 7  San Francisco       20                        1               1
# 8        Seattle       25                       10               5
#
#   emp_break_room
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# 5             No
# 6            Yes
# 7             No
# 8            Yes

# %%
plt.pie([df['avg_emp_rating'].value_counts()[1], df['avg_emp_rating'].value_counts()[2], df['avg_emp_rating'].value_counts()[3], df['avg_emp_rating'].value_counts()[4]])
# Out:
# ([<matplotlib.patches.Wedge at 0x7dac35ffbe50>,
# ...
#  [Text(1.0162674857624154, 0.4209517756015988, ''),
#   Text(0.42095177560159885, 1.0162674857624154, ''),
#   Text(-1.0162674857624154, 0.4209517756015989, ''),
#   Text(0.420951775601599, -1.0162674857624154, '')])

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/credit_apps.csv')

sns.lineplot(x='week', y='shift_am', data=df)
sns.lineplot(x='week', y='shift_pm', data=df)

# Add legend
plt.legend(labels=['AM', 'PM'])

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-science-lectures/master/emp_avg_data.csv')
df
# Out:
#        store_loc  num_emp  avg_emp_tenure_in_years  avg_emp_rating  \
# 0        Atlanta       17                        1               3
# 1         Austin       12                        6               4
# 2        Chicago       22                        3               3
# 3         Denver       21                        5               4
# 4        Detroit       10                        1               2
# 5          Miami       30                        2               3
# 6       Portland       13                        4               4
# 7  San Francisco       20                        1               1
# 8        Seattle       25                       10               5
#
#   emp_break_room
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# 5             No
# 6            Yes
# 7             No
# 8            Yes

# %%
sns.lineplot(x='avg_emp_rating', y='avg_emp_tenure_in_years', data=df, ci=None)
sns.lineplot(x='avg_emp_rating', y='num_emp', data=df, ci=None)
plt.legend(labels=['a','b', 'c', 'd', 'e'])
plt.show()
# Out:
# <ipython-input-20-1e2d56e05f4d>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='avg_emp_rating', y='avg_emp_tenure_in_years', data=df, ci=None)
# <ipython-input-20-1e2d56e05f4d>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='avg_emp_rating', y='num_emp', data=df, ci=None)

# %%
sns.lineplot(x='avg_emp_rating', y='avg_emp_tenure_in_years', data=df)
sns.lineplot(x='avg_emp_rating', y='num_emp', data=df)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
